# %% [markdown]
# # 10 Robustesse
# Analyser calibration et erreurs par sous-groupe.
#
# Version corrigée.

# %%
from pathlib import Path
import pandas as pd
from sklearn.model_selection import train_test_split
RANDOM_STATE = 42

# %%
data_path = Path('../clients_churn.csv')
df = pd.read_csv(data_path)
print(df.shape)
display(df.head())

# %% [markdown]
# ## Travail demandé
# 1. Respecter le protocole expérimental.
# 2. Justifier la métrique.
# 3. Documenter les limites.

# %%
target = 'churn_30j'
X = df.drop(columns=[target, 'client_id'])
y = df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=RANDOM_STATE)
print(X_train.shape, X_test.shape)
