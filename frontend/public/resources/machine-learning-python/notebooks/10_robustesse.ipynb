# %% [markdown]
# # 10 Robustesse
# Analyser calibration et erreurs par sous-groupe.
#
# Complétez les cellules marquées TODO.

# %%
from pathlib import Path
import pandas as pd
from sklearn.model_selection import train_test_split
RANDOM_STATE = 42

# %%
# TODO: charger le dataset adapté au module
df = None

# %% [markdown]
# ## Travail demandé
# 1. Respecter le protocole expérimental.
# 2. Justifier la métrique.
# 3. Documenter les limites.

# %%
# TODO: implémenter la solution du module
